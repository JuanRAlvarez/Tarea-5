# %% [markdown]
# # Fourier en 2 dimensiones

# %% [markdown]
# ## Autocorrelación y teorema de Khinchin-Wiener

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import scipy.fftpack

# %%
datos = loadtxt("BAO.dat")
print datos
# Out:
# [[ 0.640284  0.229898]
#  [ 0.678524  0.228967]
#  [ 0.716672  0.226175]
#  ...,
#  [-1.508242  0.461457]
#  [-1.488323  1.876118]
#  [-2.436904  1.868086]]

# %%
scatter(datos[21000:30000,0],datos[21000:30000,1],s=0.1)

# %%
#Pido prestado esto de #https://gist.github.com/thearn/5424195# 

def fft_convolve2d(x,y):
    """ 2D convolution, using FFT"""
    fr = fft2(x)
    fr2 = fft2(np.flipud(np.fliplr(y)))
    m,n = fr.shape
    cc = np.real(ifft2(fr*fr2))
    cc = np.roll(cc, -m/2+1,axis=0)
    cc = np.roll(cc, -n/2+1,axis=1)
    return cc

# %%
daticos = fft_convolve2d(datos,datos)

# %%
datotes = fft2(datos[21000:-1,:])

dats = datotes**2

datass = ifft2(dats)

plot(datass[:,0],datass[:,1],'r')

# %%
scatter(abs(daticos[:,0]),abs(daticos[:,1]))

# %%
dats = ifft2(conv)

# %%
plot( dats[:,0], dats[:,1])
