# %% [markdown]
# # Estrellas Variables RR Lyrae

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy.fftpack import fft, fftfreq

# %%
data = loadtxt("RR_Lyrae_template.dat")

print shape(data)

plot(data[:,0], data[:,1])

dt = 4.0/size(data[:,1])
# Out:
# (2000, 2)

# %%
fft_x = fft(data[:,1]) # FFT Normalized
freq = fftfreq(n, dt) # Recuperamos las frecuencias
plt.plot(freq,np.abs(fft_x))

x1,x2,y1,y2 = plt.axis()
plt.axis((-12.5,12.5,0,2000))

print freq
# Out:
# [ 0.    0.25  0.5  ..., -0.75 -0.5  -0.25]

# %% [markdown]
# ### Componentes de Fourier para $(N=0)$

# %%
fft_x = fft(data[:,1]) # FFT Normalized
freq = fftfreq(n, dt) # Recuperamos las frecuencias
#plt.plot(freq,np.abs(fft_x))

#set to 0 the values of the transform that are high:
freq_cut = 0
fft_x[np.abs(freq) > freq_cut] = 0
#plt.plot(freq,np.abs(fft_x))


#x1,x2,y1,y2 = plt.axis()
#plt.axis((-20,20,0,2000))

clean_f = ifft(fft_x)
plot(data[:,0],clean_f,c='r')
plot(data[:,0],data[:,1])

# %% [markdown]
# ### $\chi^2$ para $N=0$

# %%
plot(data[:,0],(data[:,1]-clean_f)**2)

# %% [markdown]
# ## Componentes de Fourier para $(N=1)$

# %%
fft_x = fft(data[:,1]) # FFT Normalized
freq = fftfreq(n, dt) # Recuperamos las frecuencias
#plt.plot(freq,np.abs(fft_x))

#set to 0 the values of the transform that are high:
freq_cut = 1
fft_x[np.abs(freq) > freq_cut] = 0
#plt.plot(freq,np.abs(fft_x))


#x1,x2,y1,y2 = plt.axis()
#plt.axis((-20,20,0,2000))

clean_f = ifft(fft_x)
plot(data[:,0],clean_f,c='r')
plot(data[:,0],data[:,1])

# %% [markdown]
# ### $\chi^2$ para $N=1$

# %%
plot(data[:,0],(data[:,1]-clean_f)**2)

# %% [markdown]
# ## Componentes de Fourier para $(N=2)$

# %%
fft_x = fft(data[:,1]) # FFT Normalized
freq = fftfreq(n, dt) # Recuperamos las frecuencias
#plt.plot(freq,np.abs(fft_x))

#set to 0 the values of the transform that are high:
freq_cut = 2
fft_x[np.abs(freq) > freq_cut] = 0
#plt.plot(freq,np.abs(fft_x))


#x1,x2,y1,y2 = plt.axis()
#plt.axis((-20,20,0,2000))

clean_f = ifft(fft_x)
plot(data[:,0],clean_f,c='r')
plot(data[:,0],data[:,1])

# %% [markdown]
# ### $\chi^2$ para $N=3$

# %%
plot(data[:,0],(data[:,1]-clean_f)**2)

# %% [markdown]
# ## Componentes de Fourier para $(N=3)$

# %%
fft_x = fft(data[:,1]) # FFT Normalized
freq = fftfreq(n, dt) # Recuperamos las frecuencias
#plt.plot(freq,np.abs(fft_x))

#set to 0 the values of the transform that are high:
freq_cut = 3
fft_x[np.abs(freq) > freq_cut] = 0
#plt.plot(freq,np.abs(fft_x))


#x1,x2,y1,y2 = plt.axis()
#plt.axis((-20,20,0,2000))

clean_f = ifft(fft_x)
plot(data[:,0],clean_f,c='r')
plot(data[:,0],data[:,1])

# %% [markdown]
# ### $\chi^2$ para $N=3$

# %%
plot(data[:,0],(data[:,1]-clean_f)**2)

# %% [markdown]
# ### Componentes de Fourier para $(N=4)$

# %%
fft_x = fft(data[:,1]) # FFT Normalized
freq = fftfreq(n, dt) # Recuperamos las frecuencias
#plt.plot(freq,np.abs(fft_x))

#set to 0 the values of the transform that are high:
freq_cut = 4
fft_x[np.abs(freq) > freq_cut] = 0
#plt.plot(freq,np.abs(fft_x))


#x1,x2,y1,y2 = plt.axis()
#plt.axis((-20,20,0,2000))

clean_f = ifft(fft_x)
plot(data[:,0],clean_f,c='r')
plot(data[:,0],data[:,1])

# %% [markdown]
# ### $\chi^2$ para $N=4$

# %%
plot(data[:,0],(data[:,1]-clean_f)**2)

# %% [markdown]
# ### Componentes de Fourier para $N=5$

# %%
fft_x = fft(data[:,1]) # FFT Normalized
freq = fftfreq(n, dt) # Recuperamos las frecuencias
#plt.plot(freq,np.abs(fft_x))

#set to 0 the values of the transform that are high:
freq_cut = 5
fft_x[np.abs(freq) > freq_cut] = 0
#plt.plot(freq,np.abs(fft_x))


#x1,x2,y1,y2 = plt.axis()
#plt.axis((-20,20,0,2000))

clean_f = ifft(fft_x)
plot(data[:,0],clean_f,c='r')
plot(data[:,0],data[:,1])

# %% [markdown]
# ### $\chi^2$ para $N=5$

# %%
plot(data[:,0],(data[:,1]-clean_f)**2)

# %% [markdown]
# ### Componentes de Fourier para $N=6$

# %%
fft_x = fft(data[:,1]) # FFT Normalized
freq = fftfreq(n, dt) # Recuperamos las frecuencias
#plt.plot(freq,np.abs(fft_x))

#set to 0 the values of the transform that are high:
freq_cut = 6
fft_x[np.abs(freq) > freq_cut] = 0
#plt.plot(freq,np.abs(fft_x))


#x1,x2,y1,y2 = plt.axis()
#plt.axis((-20,20,0,2000))

clean_f = ifft(fft_x)
plot(data[:,0],clean_f,c='r')
plot(data[:,0],data[:,1])

# %% [markdown]
# ### $\chi^2$ para $N=6$

# %%
plot(data[:,0],(data[:,1]-clean_f)**2)

# %% [markdown]
# ### Componentes de Fourier para $N=7$

# %%
fft_x = fft(data[:,1]) # FFT Normalized
freq = fftfreq(n, dt) # Recuperamos las frecuencias
#plt.plot(freq,np.abs(fft_x))

#set to 0 the values of the transform that are high:
freq_cut = 7
fft_x[np.abs(freq) > freq_cut] = 0
#plt.plot(freq,np.abs(fft_x))


#x1,x2,y1,y2 = plt.axis()
#plt.axis((-20,20,0,2000))

clean_f = ifft(fft_x)
plot(data[:,0],clean_f,c='r')
plot(data[:,0],data[:,1])

# %% [markdown]
# ### $\chi^2$ para $N=7$

# %%
plot(data[:,0],(data[:,1]-clean_f)**2)

# %% [markdown]
# ### Componentes de Fourier para $N=8$

# %%
fft_x = fft(data[:,1]) # FFT Normalized
freq = fftfreq(n, dt) # Recuperamos las frecuencias
#plt.plot(freq,np.abs(fft_x))

#set to 0 the values of the transform that are high:
freq_cut = 8
fft_x[np.abs(freq) > freq_cut] = 0
#plt.plot(freq,np.abs(fft_x))


#x1,x2,y1,y2 = plt.axis()
#plt.axis((-20,20,0,2000))

clean_f = ifft(fft_x)
plot(data[:,0],clean_f,c='r')
plot(data[:,0],data[:,1])

# %% [markdown]
# ### $\chi^2$ para $N=8$

# %%
plot(data[:,0],(data[:,1]-clean_f)**2)

# %% [markdown]
# ### Componentes de Fourier para $N=9$

# %%
fft_x = fft(data[:,1]) # FFT Normalized
freq = fftfreq(n, dt) # Recuperamos las frecuencias
#plt.plot(freq,np.abs(fft_x))

#set to 0 the values of the transform that are high:
freq_cut = 9
fft_x[np.abs(freq) > freq_cut] = 0
#plt.plot(freq,np.abs(fft_x))


#x1,x2,y1,y2 = plt.axis()
#plt.axis((-20,20,0,2000))

clean_f = ifft(fft_x)
plot(data[:,0],clean_f,c='r')
plot(data[:,0],data[:,1])

# %% [markdown]
# ### $\chi^2$ para $N=9$

# %%
plot(data[:,0],(data[:,1]-clean_f)**2)

# %% [markdown]
# ### Componentes de Fourier para $N=10$

# %%
fft_x = fft(data[:,1]) # FFT Normalized
freq = fftfreq(n, dt) # Recuperamos las frecuencias
#plt.plot(freq,np.abs(fft_x))

#set to 0 the values of the transform that are high:
freq_cut = 10
fft_x[np.abs(freq) > freq_cut] = 0
#plt.plot(freq,np.abs(fft_x))


#x1,x2,y1,y2 = plt.axis()
#plt.axis((-20,20,0,2000))

clean_f = ifft(fft_x)
plot(data[:,0],clean_f,c='r')
plot(data[:,0],data[:,1])

# %% [markdown]
# ### $\chi^2$ para $N=10$

# %%
plot(data[:,0],(data[:,1]-clean_f)**2)

# %% [markdown]
# ### Componentes de Fourier para $N=11$

# %%
fft_x = fft(data[:,1]) # FFT Normalized
freq = fftfreq(n, dt) # Recuperamos las frecuencias
#plt.plot(freq,np.abs(fft_x))

#set to 0 the values of the transform that are high:
freq_cut = 11
fft_x[np.abs(freq) > freq_cut] = 0
#plt.plot(freq,np.abs(fft_x))


#x1,x2,y1,y2 = plt.axis()
#plt.axis((-20,20,0,2000))

clean_f = ifft(fft_x)
plot(data[:,0],clean_f,c='r')
plot(data[:,0],data[:,1])

# %% [markdown]
# ### $\chi^2$ para $N=1$

# %%
plot(data[:,0],(data[:,1]-clean_f)**2)
